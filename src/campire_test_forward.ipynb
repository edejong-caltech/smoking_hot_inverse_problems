# %%
import importlib
import run_adv_diff_campfire
importlib.reload(run_adv_diff_campfire)
from run_adv_diff_campfire import run_toy_model
import numpy as np
# %load_ext autoreload
# %autoreload 2

# %%
# # batch case - run for all source points
# # SPECIFY SETTINGS
# n = 80                   # GRID DIMENSION: square domain
# T = 120 # number of time steps, integer

# num_faces = 2*n**2 + 2*n
# num_cells = n**2            
# S = np.array([1.0])         # List: source strengths
# sense_t = list(np.arange(1,T))     # List: sensor output times (integer times)
# sense_loc = np.array([[0.2, 0.2],[0.2,0.6],[0.6,0.2],[0.6,0.2]]) # List: sensor locations

# for i in range(n):
#     for j in range(n):
#         sources = np.array([[i/n,j/n]])
#         S_loc = sources # List: source locations in 1x1 domain
#         # Run the forward model; turn off create_gif to speed up
#         run_toy_model(n, S, S_loc, sense_t, sense_loc, create_gif=False)

# %%
# SPECIFY SETTINGS
n = 20  # GRID DIMENSION: square domain
T = 12 # number of time steps, integer
num_faces = 2*n**2 + 2*n
num_cells = n**2            
S = np.array([1.0])         # List: source strengths
S_loc = np.array([[60/80, 60/80]]) #np.array([[0.5, 0.5]]) # List: source locations in 1x1 domain
sense_t = [1,4,8,12]     # List: sensor output times (integer times)
sense_loc = np.array([[0.2, 0.2],[0.2,0.6],[0.6,0.2],[0.6,0.2]]) # List: sensor locations

# modify if velocity field/diff_coeff are different than default
# u_vel = -4.0
# v_vel = -6.0
# velocity_field = -np.ones(num_faces)*4.0
# D = 10.0
# diff_coeff = np.ones(num_cells)

# Run the forward model; turn off create_gif to speed up
run_toy_model(n, S, S_loc, sense_t, sense_loc, velocity_field=velocity_field, diff_coeff=diff_coeff, save_every=4, create_gif=True)
# Out:
# [0.00024752 0.00031222 0.00031222 0.00031222]
# [0.00749974 0.00445479 0.00445479 0.00445479]
# [0.02582247 0.00894984 0.00894984 0.00894984]
# [0.03308897 0.00973438 0.00973438 0.00973438]
# /Users/Emily/OneDrive - California Institute of Technology/2021-caltech/acm154/smoking_hot_inverse_problems/porepy/src/porepy/viz/plot_grid.py:268: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)
